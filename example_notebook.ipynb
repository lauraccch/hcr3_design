# %%
from hcr3_design import maker
# Out:
# /home/laura/miniforge3/envs/HCR_design/lib/python3.13/site-packages/Bio/Application/__init__.py:39: BiopythonDeprecationWarning: The Bio.Application modules and modules relying on it have been deprecated.
#
# Due to the on going maintenance burden of keeping command line application
# wrappers up to date, we have decided to deprecate and eventually remove these
# modules.
#
# We instead now recommend building your command line and invoking it directly
# with the subprocess module.
#   warnings.warn(

# %%
# mandatory
name = "PhiKZ014"
fullseq = "..."
amplifier = "B2"
pause = 10
polyAT = 4
polyCG = 4
numbr = 30

BlastProbes = "y"
target_organism_db = "/home/laura/Documents/Sequences/phiKZ/phiKZ_phage.fasta" #organism that contains the gene that will be targeted
background_organism_db = "/home/laura/Documents/Sequences/Pseudomonas/P_aeruginosa_PAO1.fasta" #organism that will also be present in the sample, but does not contain the sequence that is targeted with FISH
dropout = "Y"
show = "Y"
report = "Y"

# %%
maker(name, fullseq, amplifier, pause, polyAT, polyCG, BlastProbes, target_organism_db, background_organism_db, dropout, show, report, numbr)
# Out:
# Background Organism Specified, BLASTing in Progress.
# Total probes before filtering: 19
# Probes passing target & background criteria: 19
# FASTA written: PhiKZ014_final_probes.fa
# B2_PhiKZ014
#
#  Pair#  Initiator           Spacer  Probe                      Probe                      Spacer  Initiator
# ---------------------------------------------------------------------------------------------------------------------
# 1      CCTCGTAAATCCTCATCA  aa      CTTCCAATAACTAATTTGGATTTCT  ATAACCGCTTTAGAAAGAGTTTCCA  aa      ATCATCCAGTAAACCGCC
# 2      CCTCGTAAATCCTCATCA  aa      GGAGTTCACCAATAGTTTTGGGTTG  CTTCAGGGTTCTCCATTGCTTCACG  aa      ATCATCCAGTAAACCGCC
# 3      CCTCGTAAATCCTCATCA  aa      CGAGTCGTCGTACATATCAAACACA  ATCATCACTGATTTCACGCGAGCAT  aa      ATCATCCAGTAAACCGCC
# 4      CCTCGTAAATCCTCATCA  aa      TCATTCCATGAATAGCTTGATTCAT  AGATCATCATCATCCAGGGGCGTGC  aa      ATCATCCAGTAAACCGCC
# ...
